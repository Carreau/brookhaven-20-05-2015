# %% [markdown]
# # IPython & Project Jupyter

# %%
# %matplotlib inline

# %% [markdown]
# ## November 2001: "Just an afternoon hack"
#
# * [259 Line Python script](https://gist.github.com/fperez/1579699).
# * `sys.ps1` -> `In [N]`.
# * `sys.displayhook` -> `Out[N]`, *caches results*.
# * Plotting, Numeric, etc.
#
# ## Today ([Openhub stats](https://www.openhub.net/p/ipython))
#
# * 17,222 commits
# * 389 contributors
# * Total Lines : 164,413
#   - Code Lines : 96,680
# * Number of Languages : 6 (JS, CSS, HTML, ...)

# %% [markdown]
# # This is the IPython Notebook
#
# * A Web-based interactive computing system.
# * Code, results and narrative in one place.
# * Full power of modern web browsers.

# %% [markdown]
# # What does IPython actually do?

# %%
import pandas.io.data as web
from datetime import datetime

from IPython.display import display

# %%
stock = web.DataReader( 'MSFT', 'yahoo', start=datetime(2000, 1, 1))
display(stock[:3])
stock[['Open', 'Adj Close']].plot();
# Out:
#                 Open     High      Low     Close    Volume  Adj Close
# Date
# 2000-01-03  117.3750  118.625  112.000  116.5625  53228400   41.47075
# 2000-01-04  113.5625  117.125  112.250  112.6250  54119000   40.06986
# 2000-01-05  111.1250  116.375  109.375  113.8125  64059600   40.49235

# %% [markdown]
# # Browser multimedia + scientific visualization

# %%
ls *.wav
# Out:
# bird.wav

# %%
f =! ls *.wav

# %%
from talktools import *

# %%
plot_audio(f[0])

Audio(f[0])
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Mix and match languages: Julia

# %%
# %load_ext julia.magic
# Out:
# Initializing Julia interpreter. This may take some time...

# %%
# %julia @pyimport matplotlib.pyplot as plt
# %julia @pyimport numpy as np
# %matplotlib inline

# %%
# %%julia
# # Note how we mix numpy and julia:
# t = linspace(0,2*pi,1000); # use the julia linspace
# s = sin(3*t + 4*np.cos(2*t)); # use the numpy cosine and julia sine
# fig = plt.gcf()  # **** WATCH THIS VARIABLE ****
# plt.plot(t, s, color="red", linewidth=2.0, linestyle="--")

# %% [markdown]
# # Deep cross-language integration

# %%
fig = %julia fig
fig.suptitle('A simple plot')
fig

# %% [markdown]
# # The stack as a layer cake

# %%
fib = %julia fib(n, fib2) = n < 2 ? n : fib2(n-1, fib) + fib2(n-2, fib)
    
def fib2(n, fib):
    print('(P', end='')
    if n < 2:
         r = n
    else:
        print('(J',end='')
        r =  fib(n-1, fib2) + fib(n-2, fib2)
        print(')',end='')
    return r

fib2(10, fib)
# Out:
# (P(J(P(J(P(J(P(J(P(J)(P(P(P)(P(J(P(P)(P(J(P(P)(P(J))(P(J(P(J(P(P)(P(J)(P(J)(P)(P(J(P(J(P(P)(P(J)(P(J)(P)(P(J(P(J)(P(P(P))(P(J(P(J(P(J(P(P)(P(J)(P(J)(P)(P(J(P(J)(P(P(P)(P(J(P(J)(P(P(P)(P(J(P(P))(P(J(P(J(P(J(P(P)(P(J)(P(J)(P)(P(J(P(J)(P(P(P)(P(J(P(J)(P(P(P)(P(J(P(P))(P(J(P(J(P(J)(P(P(P)(P(J(P(P)(P(J(P(P)(P(J)))
# 55

# %% [markdown]
# # Comparing two images

# %%
# !wget http://www.bnl.gov/pga/images/Logo_Small.jpg
# Out:
# --2015-05-18 10:20:28--  http://www.bnl.gov/pga/images/Logo_Small.jpg
# Resolving www.bnl.gov... 130.199.3.21, 2620:10a:0:3::63
# Connecting to www.bnl.gov|130.199.3.21|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83483 (82K) [image/jpeg]
# Saving to: 'Logo_Small.jpg'
#
# Logo_Small.jpg      100%[=====================>]  81.53K   180KB/s   in 0.5s
#
# 2015-05-18 10:20:29 (180 KB/s) - 'Logo_Small.jpg' saved [83483/83483]

# %%
# !pip3 install pillow
# Out:
# Collecting pillow
#   Downloading Pillow-2.8.1-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (2.8MB)
#     100% |████████████████████████████████| 2.8MB 184kB/s
# Installing collected packages: pillow
# Successfully installed pillow-2.8.1

# %%
a.shape
# Out:
# (290, 792, 3)

# %%
a = plt.imread('Logo_Small.png')
b = plt.imread('Rev_Logo_Small.png')[:290,:,:]

def compare(a, b, s=0.5):
    c = (1-s)*a + s*b
    
    axes = plt.subplots(1,3, figsize=(18,10))[1]
    for im, ax in zip([a,b,c], axes):
        ax.imshow(im)
        ax.set_xticks([]); ax.set_yticks([])
    plt.show()
    
compare(a,b, 0.5)

# %% [markdown]
# # Can we do it interactively?

# %%
from IPython.html.widgets import interact, fixed

interact(compare, a=fixed(a), b=fixed(b), s=(0.0, 1.0));

# %% [markdown]
# # [From IPython to Juypter](jupyter-summary-ms-2014.pdf)
